# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd
import contextily as ctx
import folium

# %%
# Load the data from your CSV file
cities = pd.read_csv("minard_chard/cities.csv")
temperatures = pd.read_csv("minard_chard/temperature.csv")
troops = pd.read_csv("minard_chard/troops.csv")

# %%
cities.head()
# Out:
#    long   lat       city
# 0  24.0  55.0      Kowno
# 1  25.3  54.7      Wilna
# 2  26.4  54.4   Smorgoni
# 3  26.8  54.3  Moiodexno
# 4  27.7  55.2  Gloubokoe

# %%
# Convert the DataFrame to a GeoDataFrame
geometry = gpd.points_from_xy(cities["long"], cities["lat"])
gdf = gpd.GeoDataFrame(cities, geometry=geometry)

# Set the CRS of the GeoDataFrame to EPSG 4326 (WGS84)
gdf = gdf.set_crs(epsg=4326)

# Display the cities on a map with OpenStreetMap basemap
gdf.explore(column="city", legend=True, marker_kwds=dict(icon=folium.DivIcon()))

# %%
# Convert the cities DataFrame to a GeoDataFrame
geometry = gpd.points_from_xy(cities["long"], cities["lat"])
gdf = gpd.GeoDataFrame(cities, geometry=geometry)

# Set the CRS of the GeoDataFrame to EPSG 4326 (WGS84)
gdf = gdf.set_crs(epsg=4326)

# Merge the temperature data with the cities GeoDataFrame
gdf = gdf.merge(temperatures, on="long")

# Create a Folium map centered on the first city in the GeoDataFrame
m = folium.Map(location=[gdf["lat"].mean(), gdf["long"].mean()], zoom_start=4)

# Add the cities to the map as markers
for idx, row in gdf.iterrows():
    folium.Marker(location=[row.lat, row.long], popup=f"Temperature: {row.temp}°C").add_to(m)
    


# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8212a5ea6bebbbe98c5a24e5bfb6b9e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8212a5ea6bebbbe98c5a24e5bfb6b9e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d8212a5ea6bebbbe98c5a24e5bfb6b9e = L.map(
#                 &quot;map_d8212a5ea6bebbbe98c5a24e5bfb6b9e&quot;,
#                 {
#                     center: [54.91428571428571, 31.685714285714283],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af2d460b8c4145df129eb29b282390e6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d8212a5ea6bebbbe98c5a24e5bfb6b9e);
#
#
#             var marker_fe5ba9bee94a54107fcd26b328c42ff2 = L.marker(
#                 [54.7, 25.3],
#                 {}
#             ).addTo(map_d8212a5ea6bebbbe98c5a24e5bfb6b9e);
#
#
#         var popup_53b367d422c06c7fb9ecbaba2c2634c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_00a31d27bdd9e2ccd3853079c15e51bb = $(`&lt;div id=&quot;html_00a31d27bdd9e2ccd3853079c15e51bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Temperature: -26°C&lt;/div&gt;`)[0];
#                 popup_53b367d422c06c7fb9ecbaba2c2634c9.setContent(html_00a31d27bdd9e2ccd3853079c15e51bb);
#
#
#
#         marker_fe5ba9bee94a54107fcd26b328c42ff2.bindPopup(popup_53b367d422c06c7fb9ecbaba2c2634c9)
#         ;
#
#
#
#
#             var marker_3c8f1eff65549fe3963fbb4530acca78 = L.marker(
#                 [54.3, 28.5],
#                 {}
#             ).addTo(map_d8212a5ea6bebbbe98c5a24e5bfb6b9e);
#
#
#         var popup_ecaa497a6551c48f5202a53426455de1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ce5f649825eb83f44617ef1cdebd1fa5 = $(`&lt;div id=&quot;html_ce5f649825eb83f44617ef1cdebd1fa5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Temperature: -20°C&lt;/div&gt;`)[0];
#                 popup_ecaa497a6551c48f5202a53426455de1.setContent(html_ce5f649825eb83f44617ef1cdebd1fa5);
#
#
#
#         marker_3c8f1eff65549fe3963fbb4530acca78.bindPopup(popup_ecaa497a6551c48f5202a53426455de1)
#         ;
#
#
#
#
#             var marker_d9f11b157a53f08310744f8660d663f5 = L.marker(
#                 [54.4, 29.2],
#                 {}
#             ).addTo(map_d8212a5ea6bebbbe98c5a24e5bfb6b9e);
#
#
#         var popup_1235946ffcbde366c86b49b83cca74df = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e7abb283725c2a8c4f6394d315693778 = $(`&lt;div id=&quot;html_e7abb283725c2a8c4f6394d315693778&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Temperature: -11°C&lt;/div&gt;`)[0];
#                 popup_1235946ffcbde366c86b49b83cca74df.setContent(html_e7abb283725c2a8c4f6394d315693778);
#
#
#
#         marker_d9f11b157a53f08310744f8660d663f5.bindPopup(popup_1235946ffcbde366c86b49b83cca74df)
#         ;
#
#
#
#
#             var marker_ca014d3917e3d1878cb8949d5205c3a6 = L.marker(
#                 [54.8, 32.0],
#                 {}
#             ).addTo(map_d8212a5ea6bebbbe98c5a24e5bfb6b9e);
#
#
#         var popup_63bcf5d88e94d19abf268aa3bf70da75 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f16c7697dca728083024e2055b5514ad = $(`&lt;div id=&quot;html_f16c7697dca728083024e2055b5514ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Temperature: -21°C&lt;/div&gt;`)[0];
#                 popup_63bcf5d88e94d19abf268aa3bf70da75.setContent(html_f16c7697dca728083024e2055b5514ad);
#
#
#
#         marker_ca014d3917e3d1878cb8949d5205c3a6.bindPopup(popup_63bcf5d88e94d19abf268aa3bf70da75)
#         ;
#
#
#
#
#             var marker_6e1628095aee3d643cf5bd1d03d290d8 = L.marker(
#                 [54.9, 33.2],
#                 {}
#             ).addTo(map_d8212a5ea6bebbbe98c5a24e5bfb6b9e);
#
#
#         var popup_ed1f31c0bef9e25f5e36a32cffd023f5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f37a2bbe5f201c474d74a7b5d0c3c7b2 = $(`&lt;div id=&quot;html_f37a2bbe5f201c474d74a7b5d0c3c7b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Temperature: -9°C&lt;/div&gt;`)[0];
#                 popup_ed1f31c0bef9e25f5e36a32cffd023f5.setContent(html_f37a2bbe5f201c474d74a7b5d0c3c7b2);
#
#
#
#         marker_6e1628095aee3d643cf5bd1d03d290d8.bindPopup(popup_ed1f31c0bef9e25f5e36a32cffd023f5)
#         ;
#
#
#
#
#             var marker_d38493712dda0079655f4980c525c9e3 = L.marker(
#                 [55.5, 36.0],
#                 {}
#             ).add

# %%
# Convert the DataFrame to a GeoDataFrame
geometry = gpd.points_from_xy(cities["long"], cities["lat"])
gdf = gpd.GeoDataFrame(cities, geometry=geometry)

# Set the CRS of the GeoDataFrame to EPSG 4326 (WGS84)
gdf = gdf.set_crs(epsg=4326)

# Display the cities on a map with OpenStreetMap basemap
gdf.explore(column="city", legend=True, marker_kwds=dict(icon=folium.DivIcon()))


# Merge the temperature data with the cities GeoDataFrame
gdf = gdf.merge(temperatures, on="long")

# Create a Folium map centered on the mean latitude and longitude of all the cities in the GeoDataFrame
m = folium.Map(location=[gdf["lat"].mean(), gdf["long"].mean()], zoom_start=4)

# Add the cities to the map as markers with temperature information
for idx, row in gdf.iterrows():
    folium.Marker(location=[row.lat, row.long], popup=f"Temperature: {row.temp}°C").add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cd782af667dce21dc001dfd79c37436b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cd782af667dce21dc001dfd79c37436b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cd782af667dce21dc001dfd79c37436b = L.map(
#                 &quot;map_cd782af667dce21dc001dfd79c37436b&quot;,
#                 {
#                     center: [54.91428571428571, 31.685714285714283],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_00f2aaaaa1b21ee5342e5e25fb3923a5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cd782af667dce21dc001dfd79c37436b);
#
#
#             var marker_3daea1c0a6c2f2c4298bee1137a613f7 = L.marker(
#                 [54.7, 25.3],
#                 {}
#             ).addTo(map_cd782af667dce21dc001dfd79c37436b);
#
#
#         var popup_fbc35f659e2c7ee1f84b468f08e589d6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4dda15f66a7fdeba781b0c0dc1e14c8e = $(`&lt;div id=&quot;html_4dda15f66a7fdeba781b0c0dc1e14c8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Temperature: -26°C&lt;/div&gt;`)[0];
#                 popup_fbc35f659e2c7ee1f84b468f08e589d6.setContent(html_4dda15f66a7fdeba781b0c0dc1e14c8e);
#
#
#
#         marker_3daea1c0a6c2f2c4298bee1137a613f7.bindPopup(popup_fbc35f659e2c7ee1f84b468f08e589d6)
#         ;
#
#
#
#
#             var marker_87e9e80053243aa6bdc850854f6b1d9d = L.marker(
#                 [54.3, 28.5],
#                 {}
#             ).addTo(map_cd782af667dce21dc001dfd79c37436b);
#
#
#         var popup_43d1a19ac517fb682949e025a1102db4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_770605962a79ade4f44073c52eb6a23b = $(`&lt;div id=&quot;html_770605962a79ade4f44073c52eb6a23b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Temperature: -20°C&lt;/div&gt;`)[0];
#                 popup_43d1a19ac517fb682949e025a1102db4.setContent(html_770605962a79ade4f44073c52eb6a23b);
#
#
#
#         marker_87e9e80053243aa6bdc850854f6b1d9d.bindPopup(popup_43d1a19ac517fb682949e025a1102db4)
#         ;
#
#
#
#
#             var marker_ca21a5878e8a6582fc2830b79ed13df0 = L.marker(
#                 [54.4, 29.2],
#                 {}
#             ).addTo(map_cd782af667dce21dc001dfd79c37436b);
#
#
#         var popup_ab9e14fef6a95fe369c1c22982bcc42e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54c5da496050ca706c4c2a127bb9c19a = $(`&lt;div id=&quot;html_54c5da496050ca706c4c2a127bb9c19a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Temperature: -11°C&lt;/div&gt;`)[0];
#                 popup_ab9e14fef6a95fe369c1c22982bcc42e.setContent(html_54c5da496050ca706c4c2a127bb9c19a);
#
#
#
#         marker_ca21a5878e8a6582fc2830b79ed13df0.bindPopup(popup_ab9e14fef6a95fe369c1c22982bcc42e)
#         ;
#
#
#
#
#             var marker_0dfb1dd535e38edcdd95ba28fba37321 = L.marker(
#                 [54.8, 32.0],
#                 {}
#             ).addTo(map_cd782af667dce21dc001dfd79c37436b);
#
#
#         var popup_f045c97f3af5410a3b50653244ce71c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_41e836eb56374d758a027e20a1c216d4 = $(`&lt;div id=&quot;html_41e836eb56374d758a027e20a1c216d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Temperature: -21°C&lt;/div&gt;`)[0];
#                 popup_f045c97f3af5410a3b50653244ce71c4.setContent(html_41e836eb56374d758a027e20a1c216d4);
#
#
#
#         marker_0dfb1dd535e38edcdd95ba28fba37321.bindPopup(popup_f045c97f3af5410a3b50653244ce71c4)
#         ;
#
#
#
#
#             var marker_6acb18d06ace8b9e6258061adb2109ba = L.marker(
#                 [54.9, 33.2],
#                 {}
#             ).addTo(map_cd782af667dce21dc001dfd79c37436b);
#
#
#         var popup_b2c0fd5d31d36c7f6a845633dd948335 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a4e3c408bfbcd8435cef66b100936199 = $(`&lt;div id=&quot;html_a4e3c408bfbcd8435cef66b100936199&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Temperature: -9°C&lt;/div&gt;`)[0];
#                 popup_b2c0fd5d31d36c7f6a845633dd948335.setContent(html_a4e3c408bfbcd8435cef66b100936199);
#
#
#
#         marker_6acb18d06ace8b9e6258061adb2109ba.bindPopup(popup_b2c0fd5d31d36c7f6a845633dd948335)
#         ;
#
#
#
#
#             var marker_3dee11c8ef54f4faf87949ba63b72761 = L.marker(
#                 [55.5, 36.0],
#                 {}
#             ).add

# %%
troops = troops.sort_values(by=["division", "survivors"], ascending=False)

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.scatterplot(data=troops, x='long', y='lat', size='survivors', hue='direction', sizes=(1, 75), ax=ax)
ax.set_aspect("equal")
ax.set_xlim(troops['long'].min(), troops['long'].max())
ax.set_ylim(troops['lat'].min(), troops['lat'].max())
ax.legend().remove()
plt.savefig("troops_first_try.png")
plt.close()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.scatterplot(data=troops, x='long', y='lat', size='survivors', hue='direction', sizes=(1, 75), ax=ax)
ax.set_aspect("equal")
ax.set_xlim(troops['long'].min(), troops['long'].max())
ax.set_ylim(troops['lat'].min(), troops['lat'].max())
ax.legend().remove()
plt.savefig("troops.png")
plt.close()

# %%
troops_text = troops.iloc[::2, :].copy()
troops_text["long"] += 0.13 * (troops_text["division"])
troops_text["lat"] += troops_text["direction"].replace({"A": 0.35, "R": -0.21})

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.scatterplot(data=troops_text, x='long', y='lat', size='survivors', ax=ax)
ax.set_aspect("equal")
ax.set_xlim(troops_text['long'].min(), troops_text['long'].max())
ax.set_ylim(troops_text['lat'].min(), troops_text['lat'].max())
plt.savefig("troops_text.png")
plt.close()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.scatterplot(data=cities, x='long', y='lat', ax=ax)
ax.set_aspect("equal")
ax.set_xlim(cities['long'].min(), cities['long'].max())
ax.set_ylim(cities['lat'].min(), cities['lat'].max())
plt.savefig("cities.png")
plt.close()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=temperatures, x='long', y='temp', color="#888888", ax=ax)
scatter = sns.scatterplot(data=temperatures, x='long', y='temp', ax=ax)

# Add text labels to the scatter plot
for i, row in temperatures.iterrows():
    if pd.notnull(row["temp"]):
        scatter.annotate(row["label"], xy=(row["long"], row["temp"]), xytext=(5, 5), textcoords="offset points")

plt.savefig("temperature.png")
plt.close()

# %%
fig, axes = plt.subplots(nrows=2, figsize=(10, 10))
sns.scatterplot(data=troops, x='long', y='lat', size='survivors', hue='direction', sizes=(1, 75), ax=axes[0])
axes[0].set_aspect("equal")
axes[0].set_xlim(troops['long'].min(), troops['long'].max())
axes[0].set_ylim(troops['lat'].min(), troops['lat'].max())
axes[0].legend().remove()

sns.lineplot(data=temperatures, x='long', y='temp', color="#888888", ax=axes[1])
scatter = sns.scatterplot(data=temperatures, x='long', y='temp', ax=axes[1])

# Add text labels to the scatter plot
for i, row in temperatures.iterrows():
    if pd.notnull(row["temp"]):
        scatter.annotate(row["label"], xy=(row["long"], row["temp"]), xytext=(5, 5), textcoords="offset points")

plt.tight_layout()
plt.savefig("minard_chart.png")
