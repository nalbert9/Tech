# %%
# Import librairies
import pandas as pd
import altair as alt
import numpy as np
from vega_datasets import data

# %%
# Load data
cities = pd.read_csv("minard_chard/cities.csv")
temperatures = pd.read_csv("minard_chard/temperature.csv")
troops = pd.read_csv("minard_chard/troops.csv")

# %%
# Create a label for temperatures
temperatures["label"] = temperatures.fillna("").apply(
    axis=1, func=lambda row: "{}° {}".format(row[1], row[3].replace("-", " "))
)
temperatures.head()
# Out:
#    long  temp     day       date           label
# 0  37.6     0  Oct 18  18OCT1812    0° 18OCT1812
# 1  36.0     0  Oct 24  24OCT1812    0° 24OCT1812
# 2  33.2    -9   Nov 9  09NOV1812   -9° 09NOV1812
# 3  32.0   -21  Nov 14  14NOV1812  -21° 14NOV1812
# 4  29.2   -11  Nov 24  24NOV1812  -11° 24NOV1812

# %%
troops = troops.sort_values(by=["division", "survivors"], ascending=False)
troops.head()
# Out:
#     long   lat  survivors direction  division
# 45  24.0  55.2      22000         A         3
# 46  24.5  55.3      22000         A         3
# 47  24.6  55.8       6000         A         3
# 48  24.6  55.8       6000         R         3
# 49  24.2  54.4       6000         R         3

# %%
# Sort troops data
troops_chart = alt.Chart(troops).mark_trail().encode(
    x='long:Q',
    y='lat:Q',
    size=alt.Size('survivors', scale=alt.Scale(range=[1, 75]), legend=None),
    color=alt.Color('direction')
)
troops_chart.save("troops_first_try.html")
troops_chart
# Out:
# alt.Chart(...)

# %%
# Create troops chart
troops_chart = alt.Chart(troops).mark_trail().encode(
    longitude='long:Q',
    latitude='lat:Q',
    size=alt.Size(
        'survivors', 
        scale=alt.Scale(range=[1, 75]), 
        legend=None
    ),
    detail='division',
    color=alt.Color(
        'direction', 
        scale=alt.Scale(
            domain=['A', 'R'],
            range=['#EBD2A8', '#888888']
        ), 
        legend=None
    ),
).project(
    type="mercator"
)
troops_chart.save("troops.html")
troops_chart
# Out:
# alt.Chart(...)

# %%
# Manipulate troops data for text chart
troops_text = troops.iloc[::2, :].copy()
troops_text["long"] += 0.13 * (troops_text["division"])
troops_text["lat"] += troops_text["direction"].replace({"A": 0.35, "R": -0.21})
troops_text.head()
# Out:
#      long    lat  survivors direction  division
# 45  24.39  55.55      22000         A         3
# 47  24.99  56.15       6000         A         3
# 49  24.59  54.19       6000         R         3
# 35  24.26  55.45      60000         A         2
# 37  25.76  55.05      60000         A         2

# %%
# Create troops text chart
troops_text_chart = alt.Chart(troops_text).mark_text(
    font='Cardo',
    fontSize=7,
    fontStyle='italic',
    angle=280
).encode(
    longitude='long:Q',
    latitude='lat:Q',
    text='survivors'
).project(
    type="mercator"
)
troops_text_chart.save("troops_text.html")
troops_text_chart
# Out:
# alt.Chart(...)

# %%
# Create cities chart
cities_chart = alt.Chart(cities).mark_text(
    font='Cardo',
    fontSize=11,
    fontStyle='italic',
    dx=-3
).encode(
    longitude='long:Q',
    latitude='lat:Q',
    text='city',
).project(
    type="mercator"
)
cities_chart.save("cities.html")
cities_chart
# Out:
# alt.Chart(...)

# %%
# Create temperatures chart
x_encode = alt.X(
    'long:Q', 
    scale=alt.Scale(
        domain=[cities["long"].min(), cities["long"].max()]
    ),
    axis=None
)

y_encode = alt.Y(
    'temp',
    axis=alt.Axis(
        title="Temperature on Retreat", 
        grid=True, 
        orient='right'
    )
)

temperatures_chart = alt.Chart(temperatures).mark_line(
    color="#888888"
).encode(
    x=x_encode,
    y=y_encode
) + alt.Chart(temperatures).mark_text(
    dx=5, 
    dy=20, 
    font='Cardo', 
    fontSize=10
).encode(
    x=x_encode,
    y=y_encode,
    text='label'
)
temperatures_chart.save("temperature.html")

temperatures_chart = temperatures_chart.properties(
    height=100
)
temperatures_chart
# Out:
# alt.LayerChart(...)

# %%
# Combine all charts into a final chart
map_chart = troops_chart + cities_chart + troops_text_chart
map_chart
# Out:
# alt.LayerChart(...)

# %%
final_chart = alt.vconcat(map_chart, temperatures_chart).configure(
    view=alt.ViewConfig(
        width=900,
        height=400,
        strokeWidth=0
    ),
    axis=alt.AxisConfig(
        grid=False,
        labelFont="Cardo",
        titleFont="Cardo"
    )
)
final_chart.save("minard_chart.html")
# Out:
# ---------------------------------------------------------------------------
# SchemaValidationError                     Traceback (most recent call last)
# Cell In[26], line 2
#       1 final_chart = alt.vconcat(map_chart, temperatures_chart).configure(
# ----> 2     view=alt.ViewConfig(
#       3         width=900,
#       4         height=400,
#       5         strokeWidth=0
#       6     ),
#       7     axis=alt.AxisConfig(
#       8         grid=False,
#       9         labelFont="Cardo",
#      10         titleFont="Cardo"
#      11     )
#      12 )
#      13 final_chart.save("minard_chart.html")
#
# File ~/anaconda3/lib/python3.11/site-packages/altair/vegalite/v5/schema/core.py:21838, in ViewConfig.__init__(self, clip, continuousHeight, continuousWidth, cornerRadius, cursor, discreteHeight, discreteWidth, fill, fillOpacity, opacity, step, stroke, strokeCap, strokeDash, strokeDashOffset, strokeJoin, strokeMiterLimit, strokeOpacity, strokeWidth, **kwds)
#   21832 def __init__(self, clip=Undefined, continuousHeight=Undefined, continuousWidth=Undefined,
#   21833              cornerRadius=Undefined, cursor=Undefined, discreteHeight=Undefined,
#   21834              discreteWidth=Undefined, fill=Undefined, fillOpacity=Undefined, opacity=Undefined,
#   21835              step=Undefined, stroke=Undefined, strokeCap=Undefined, strokeDash=Undefined,
#   21836              strokeDashOffset=Undefined, strokeJoin=Undefined, strokeMiterLimit=Undefined,
#   21837              strokeOpacity=Undefined, strokeWidth=Undefined, **kwds):
# > 21838     super(ViewConfig, self).__init__(clip=clip, continuousHeight=continuousHeight,
#   21839                                      continuousWidth=continuousWidth, cornerRadius=cornerRadius,
#   21840                                      cursor=cursor, discreteHeight=discreteHeight,
#   21841                                      discreteWidth=discreteWidth, fill=fill,
#   21842                                      fillOpacity=fillOpacity, opacity=opacity, step=step,
#   21843                                      stroke=stroke, strokeCap=strokeCap, strokeDash=strokeDash,
#   21844                                      strokeDashOffset=strokeDashOffset, strokeJoin=strokeJoin,
#   21845                                      strokeMiterLimit=strokeMiterLimit, strokeOpacity=strokeOpacity,
#   21846                                      strokeWidth=strokeWidth, **kwds)
#
# File ~/anaconda3/lib/python3.11/site-packages/altair/utils/schemapi.py:776, in SchemaBase.__init__(self, *args, **kwds)
#     773 object.__setattr__(self, "_kwds", kwds)
#     775 if DEBUG_MODE and self._class_is_valid_at_instantiation:
# --> 776     self.to_dict(validate=True)
#
# File ~/anaconda3/lib/python3.11/site-packages/altair/utils/schemapi.py:983, in SchemaBase.to_dict(self, validate, ignore, context)
#     976         self.validate(result)
#     977     except jsonschema.ValidationError as err:
#     978         # We do not raise `from err` as else the resulting
#     979         # traceback is very long as it contains part
#     980         # of the Vega-Lite schema. It would also first
#     981         # show the less helpful ValidationError instead of
#     982         # the more user friendly SchemaValidationError
# --> 983         raise SchemaValidationError(self, err) from None
#     984 return result
#
# SchemaValidationError: `ViewConfig` has no parameter named 'height'
#
# Existing parameter names are:
# clip               cursor           fillOpacity   strokeCap          strokeMiterLimit
# continuousHeight   discreteHeight   opacity       strokeDash         strokeOpacity
# continuousWidth    discreteWidth    step          strokeDashOffset   strokeWidth
# cornerRadius       fill             stroke        strokeJoin
#
# See the help for `ViewConfig` to read the full description of these parameters
